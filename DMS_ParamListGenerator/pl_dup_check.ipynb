# %%
import pandas as pd

# %%
pl_clean = pd.read_csv("mappings/REF_2026-04-20_ParameterLists_Export.csv")
pl_clean = pl_clean.groupby("Parameter short name")["Name"].nunique()

dup_check = pl_clean[pl_clean > 1]
dup_check
# Out:
# Series([], Name: Name, dtype: int64)
